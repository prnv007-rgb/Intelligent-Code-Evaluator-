# %%
import os
import json
import re

def extract_fields_from_py(filepath):
    with open(filepath, "r", encoding="utf-8") as f:
        lines = f.readlines()

    title = description = time = space = ""
    tags = []
    code_lines = []

    for line in lines:
        if line.strip().startswith("#"):
            line = line.strip()[1:].strip()
            if line.lower().startswith("title:"):
                title = line.split(":", 1)[1].strip()
            elif line.lower().startswith("description:"):
                description = line.split(":", 1)[1].strip()
            elif line.lower().startswith("time complexity:"):
                time = line.split(":", 1)[1].strip()
            elif line.lower().startswith("space complexity:"):
                space = line.split(":", 1)[1].strip()
            elif line.lower().startswith("tags:"):
                tags = [tag.strip() for tag in line.split(":", 1)[1].split(",")]
        else:
            code_lines.append(line)

    return {
        "title": title,
        "description": description,
        "optimal_code": "".join(code_lines).strip(),
        "time_complexity": time,
        "space_complexity": space,
        "tags": tags
    }

def convert_all_py_to_json(directory, output_path="neetcode_problems.json"):
    problems = []
    for filename in os.listdir(directory):
        if filename.endswith(".py"):
            full_path = os.path.join(directory, filename)
            problem = extract_fields_from_py(full_path)
            problems.append(problem)

    with open('\out/', "w", encoding="utf-8") as out:
        json.dump(problems, out, indent=2)

    print(f"✅ Saved {len(problems)} problems to {output_path}")

# Run this script
if __name__ == "__main__":
    convert_all_py_to_json("npy/leetcode/python")
# Out:
# <>:46: SyntaxWarning: invalid escape sequence '\o'
# <>:46: SyntaxWarning: invalid escape sequence '\o'
# C:\Windows\Temp\ipykernel_6096\4205748069.py:46: SyntaxWarning: invalid escape sequence '\o'
#   with open('\out/', "w", encoding="utf-8") as out:
# C:\Windows\Temp\ipykernel_6096\4205748069.py:46: SyntaxWarning: invalid escape sequence '\o'
#   with open('\out/', "w", encoding="utf-8") as out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 53
#      51 # Run this script
#      52 if __name__ == "__main__":
# ---> 53     convert_all_py_to_json("npy/leetcode/python")
#
# Cell In[1], line 46, in convert_all_py_to_json(directory, output_path)
#      43         problem = extract_fields_from_py(full_path)
#      44         problems.append(problem)
# ---> 46 with open('\out/', "w", encoding="utf-8") as out:
#      47     json.dump(problems, out, indent=2)
#      49 print(f"✅ Saved {len(problems)} problems to {output_path}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:327, in _modified_open(file, *args, **kwargs)
#     320 if file in {0, 1, 2}:
#     321     raise ValueError(
#     322         f"IPython won't let you open fd={file} by default "
#     323         "as it is likely to crash IPython. If you know what you are doing, "
#     324         "you can use builtins' open."
#     325     )
# --> 327 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: '\\out/'

# %%
import os
import json

def extract_fields_from_py(filepath):
    title = description = time = space = ""
    tags = []
    code_lines = []

    with open(filepath, 'r', encoding='utf-8') as f:
        for raw in f:
            line = raw.rstrip('\n')
            if line.lstrip().startswith('#'):
                meta = line.lstrip()[1:].strip()
                if meta.lower().startswith('title:'):
                    title = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('description:'):
                    description = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('time complexity:'):
                    time = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('space complexity:'):
                    space = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('tags:'):
                    tags = [t.strip() for t in meta.split(':', 1)[1].split(',')]
            else:
                code_lines.append(raw)

    return {
        "title": title,
        "description": description,
        "optimal_code": "".join(code_lines).rstrip(),
        "time_complexity": time,
        "space_complexity": space,
        "tags": tags
    }

def convert_all_py_to_json(py_dir, output_path):
    if not os.path.isdir(py_dir):
        print(f"❌ Source directory not found: {py_dir}")
        return

    os.makedirs(os.path.dirname(output_path) or ".", exist_ok=True)

    problems = []
    for fname in sorted(os.listdir(py_dir)):
        if not fname.lower().endswith('.py'):
            continue
        full = os.path.join(py_dir, fname)
        try:
            entry = extract_fields_from_py(full)
            if entry['title'] and entry['optimal_code']:
                problems.append(entry)
            else:
                print(f"⚠️  Skipping {fname}: missing title or code")
        except Exception as e:
            print(f"❌ Error processing {fname}: {e}")

    with open(output_path, 'w', encoding='utf-8') as out:
        json.dump(problems, out, indent=2, ensure_ascii=False)

    print(f"✅ Converted {len(problems)} problems → {output_path}")

# %%
convert_all_py_to_json("npy/leetcode/python", "neetcode_problems.json")
# Out:
# ⚠️  Skipping 0001-two-sum.py: missing title or code
# ⚠️  Skipping 0002-add-two-numbers.py: missing title or code
# ⚠️  Skipping 0003-longest-substring-without-repeating-characters.py: missing title or code
# ⚠️  Skipping 0004-median-of-two-sorted-arrays.py: missing title or code
# ⚠️  Skipping 0005-longest-palindromic-substring.py: missing title or code
# ⚠️  Skipping 0006-zigzag-conversion.py: missing title or code
# ⚠️  Skipping 0007-reverse-integer.py: missing title or code
# ⚠️  Skipping 0009-palindrome-number.py: missing title or code
# ⚠️  Skipping 0010-regular-expression-matching.py: missing title or code
# ⚠️  Skipping 0011-container-with-most-water.py: missing title or code
# ⚠️  Skipping 0012-integer-to-roman.py: missing title or code
# ⚠️  Skipping 0013-roman-to-integer.py: missing title or code
# ⚠️  Skipping 0014-longest-common-prefix.py: missing title or code
# ⚠️  Skipping 0015-3sum.py: missing title or code
# ⚠️  Skipping 0016-3sum-closest.py: missing title or code
# ⚠️  Skipping 0017-letter-combinations-of-a-phone-number.py: missing title or code
# ⚠️  Skipping 0018-4sum.py: missing title or code
# ⚠️  Skipping 0019-remove-nth-node-from-end-of-list.py: missing title or code
# ⚠️  Skipping 0020-valid-parentheses.py: missing title or code
# ⚠️  Skipping 0021-merge-two-sorted-lists.py: missing title or code
# ⚠️  Skipping 0022-generate-parentheses.py: missing title or code
# ⚠️  Skipping 0023-merge-k-sorted-lists.py: missing title or code
# ⚠️  Skipping 0024-swap-nodes-in-pairs.py: missing title or code
# ⚠️  Skipping 0025-reverse-nodes-in-k-group.py: missing title or code
# ⚠️  Skipping 0026-remove-duplicates-from-sorted-array.py: missing title or code
# ⚠️  Skipping 0027-remove-element.py: missing title or code
# ⚠️  Skipping 0028-find-the-index-of-the-first-occurrence-in-a-string.py: missing title or code
# ⚠️  Skipping 0033-search-in-rotated-sorted-array.py: missing title or code
# ⚠️  Skipping 0034-find-first-and-last-position-of-element-in-sorted-array.py: missing title or code
# ⚠️  Skipping 0035-search-insert-position.py: missing title or code
# ⚠️  Skipping 0036-valid-sudoku.py: missing title or code
# ⚠️  Skipping 0039-combination-sum.py: missing title or code
# ⚠️  Skipping 0040-combination-sum-ii.py: missing title or code
# ⚠️  Skipping 0041-first-missing-positive.py: missing title or code
# ⚠️  Skipping 0042-trapping-rain-water.py: missing title or code
# ⚠️  Skipping 0043-multiply-strings.py: missing title or code
# ⚠️  Skipping 0044-wildcard-matching.py: missing title or code
# ⚠️  Skipping 0045-jump-game-ii.py: missing title or code
# ⚠️  Skipping 0046-permutations.py: missing title or code
# ⚠️  Skipping 0047-permutations-ii.py: missing title or code
# ⚠️  Skipping 0048-rotate-image.py: missing title or code
# ⚠️  Skipping 0049-group-anagrams.py: missing title or code
# ⚠️  Skipping 0050-powx-n.py: missing title or code
# ⚠️  Skipping 0051-n-queens.py: missing title or code
# ⚠️  Skipping 0052-n-queens-ii.py: missing title or code
# ⚠️  Skipping 0053-maximum-subarray.py: missing title or code
# ⚠️  Skipping 0054-spiral-matrix.py: missing title or code
# ⚠️  Skipping 0055-jump-game.py: missing title or code
# ⚠️  Skipping 0056-merge-intervals.py: missing title or code
# ⚠️  Skipping 0057-insert-interval.py: missing title or code
# ⚠️  Skipping 0058-length-of-last-word.py: missing title or code
# ⚠️  Skipping 0061-rotate-list.py: missing title or code
# ⚠️  Skipping 0062-unique-paths.py: missing title or code
# ⚠️  Skipping 0063-unique-paths-ii.py: missing title or code
# ⚠️  Skipping 0064-minimum-path-sum.py: missing title or code
# ⚠️  Skipping 0066-plus-one.py: missing title or code
# ⚠️  Skipping 0067-add-binary.py: missing title or code
# ⚠️  Skipping 0068-text-justification.py: missing title or code
# ⚠️  Skipping 0069-sqrtx.py: missing title or code
# ⚠️  Skipping 0070-climbing-stairs.py: missing title or code
# ⚠️  Skipping 0071-simplify-path.py: missing title or code
# ⚠️  Skipping 0072-edit-distance.py: missing title or code
# ⚠️  Skipping 0073-set-matrix-zeroes.py: missing title or code
# ⚠️  Skipping 0074-search-a-2d-matrix.py: missing title or code
# ⚠️  Skipping 0075-sort-colors.py: missing title or code
# ⚠️  Skipping 0076-minimum-window-substring.py: missing title or code
# ⚠️  Skipping 0077-combinations.py: missing title or code
# ⚠️  Skipping 0078-subsets.py: missing title or code
# ⚠️  Skipping 0079-word-search.py: missing title or code
# ⚠️  Skipping 0080-remove-duplicates-from-sorted-array-ii.py: missing title or code
# ⚠️  Skipping 0081-search-in-rotated-sorted-array-ii.py: missing title or code
# ⚠️  Skipping 0083-remove-duplicates-from-sorted-list.py: missing title or code
# ⚠️  Skipping 0084-largest-rectangle-in-histogram.py: missing title or code
# ⚠️  Skipping 0086-partition-list.py: missing title or code
# ⚠️  Skipping 0088-merge-sorted-array.py: missing title or code
# ⚠️  Skipping 0090-subsets-ii.py: missing title or code
# ⚠️  Skipping 0091-decode-ways.py: missing title or code
# ⚠️  Skipping 0092-reverse-linked-list-ii.py: missing title or code
# ⚠️  Skipping 0094-binary-tree-inorder-traversal.py: missing title or code
# ⚠️  Skipping 0097-interleaving-string.py: missing title or code
# ⚠️  Skipping 0098-validate-binary-search-tree.py: missing title or code
# ⚠️  Skipping 0100-same-tree.py: missing title or code
# ⚠️  Skipping 0101-symmetric-tree.py: missing title or code
# ⚠️  Skipping 0102-binary-tree-level-order-traversal.py: missing title or code
# ⚠️  Skipping 0103-binary-tree-zigzag-level-order-traversal.py: missing title or code
# ⚠️  Skipping 0104-maximum-depth-of-binary-tree.py: missing title or code
# ⚠️  Skipping 0105-construct-binary-tree-from-preorder-and-inorder-traversal.py: missing title or code
# ⚠️  Skipping 0106-construct-binary-tree-from-inorder-and-postorder-traversal.py: missing title or code
# ⚠️  Skipping 0108-convert-sorted-array-to-binary-search-tree.py: missing title or code
# ⚠️  Skipping 0110-balanced-binary-tree.py: missing title or code
# ⚠️  Skipping 0112-path-sum.py: missing title or code
# ⚠️  Skipping 0115-distinct-subsequences.py: missing title or code
# ⚠️  Skipping 0118-pascals-triangle.py: missing title or code
# ⚠️  Skipping 0119-pascal-triangle-ii.py: missing title or code
# ⚠️  Skipping 0120-triangle.py: missing title or code
# ⚠️  Skipping 0121-best-time-to-buy-and-sell-stock.py: missing title or code
# ⚠️  Skipping 0122-best-time-to-buy-and-sell-stock-ii.py: missing title or code
# ⚠️  Skipping 0124-binary-tree-maximum-path-sum.py: missing title or code
# ⚠️  Skipping 0125-valid-palindrome.py: missing title or code
# ⚠️  Skipping 0127-word-ladder.py: missing title or code
# ⚠️  Skipping 0128-longest-consecutive-sequence.py: missing title or code
# ⚠️  Skipping 0130-surrounded-regions.py: missing title or code
# ⚠️  Skipping 0131-palindrome-partitioning.py: missing title or code
# ⚠️  Skipping 0133-clone-graph.py: missing title or code
# ⚠️  Skipping 0134-gas-station.py: missing title or code
# ⚠️  Skipping 0135-candy.py: missing title or code
# ⚠️  Skipping 0136-single-number.py: missing title or code
# ⚠️  Skipping 0138-copy-list-with-random-pointer.py: missing title or code
# ⚠️  Skipping 0139-word-break.py: missing title or code
# ⚠️  Skipping 0141-linked-list-cycle.py: missing title or code
# ⚠️  Skipping 0143-reorder-list.py: missing title or code
# ⚠️  Skipping 0144-binary-tree-preorder-traversal.py: missing title or code
# ⚠️  Skipping 0145-binary-tree-postorder-traversal.py: missing title or code
# ⚠️  Skipping 0146-lru-cache.py: missing title or code
# ⚠️  Skipping 0147-insertion-sort-list.py: missing title or code
# ⚠️  Skipping 0148-sort-list.py: missing title or code
# ⚠️  Skipping 0149-max-points-on-a-line.py: missing title or code
# ⚠️  Skipping 0150-evaluate-reverse-polish-notation.py: missing title or code
# ⚠️  Skipping 0151-reverse-words-in-a-string.py: missing title or code
# ⚠️  Skipping 0152-maximum-product-subarray.py: missing title or code
# ⚠️  Skipping 0153-find-minimum-in-rotated-sorted-array.py: missing title or code
# ⚠️  Skipping 0155-min-stack.py: missing title or code
# ⚠️  Skipping 0160-intersection-of-two-linked-lists.py: missing title or code
# ⚠️  Skipping 0162-find-peak-element.py: missing title or code
# ⚠️  Skipping 0167-two-sum-ii-input-array-is-sorted.py: missing title or code
# ⚠️  Skipping 0168-excel-sheet-column-title.py: missing title or code
# ⚠️  Skipping 0169-majority-element.py: missing title or code
# ⚠️  Skipping 0179-largest-number.py: missing title or code
# ⚠️  Skipping 0187-repeated-dna-sequences.py: missing title or code
# ⚠️  Skipping 0189-rotate-array.py: missing title or code
# ⚠️  Skipping 0190-reverse-bits.py: missing title or code
# ⚠️  Skipping 0191-number-of-1-bits.py: missing title or code
# ⚠️  Skipping 0198-house-robber.py: missing title or code
# ⚠️  Skipping 0199-binary-tree-right-side-view.py: missing title or code
# ⚠️  Skipping 0200-number-of-islands.py: missing title or code
# ⚠️  Skipping 0201-bitwise-and-of-numbers-range.py: missing title or code
# ⚠️  Skipping 0202-happy-number.py: missing title or code
# ⚠️  Skipping 0203-remove-linked-list-elements.py: missing title or code
# ⚠️  Skipping 0205-isomorphic-strings.py: missing title or code
# ⚠️  Skipping 0206-reverse-linked-list.py: missing title or code
# ⚠️  Skipping 0207-course-schedule.py: missing title or code
# ⚠️  Skipping 0208-implement-trie-prefix-tree.py: missing title or code
# ⚠️  Skipping 0209-minimum-size-subarray-sum.py: missing title or code
# ⚠️  Skipping 0210-course-schedule-ii.py: missing title or code
# ⚠️  Skipping 0211-design-add-and-search-words-data-structure.py: missing title or code
# ⚠️  Skipping 0212-word-search-ii.py: missing title or code
# ⚠️  Skipping 0213-house-robber-ii.py: missing title or code
# ⚠️  Skipping 0215-kth-largest-element-in-an-array.py: missing title or code
# ⚠️  Skipping 0217-contains-duplicate.py: missing title or code
# ⚠️  Skipping 0219-contains-duplicate-ii.py: missing title or code
# ⚠️  Skipping 0221-maximal-square.py: missing title or code
# ⚠️  Skipping 0225-implement-stack-using-queues.py: missing title or code
# ⚠️  Skipping 0226-invert-binary-tree.py: missing title or code
# ⚠️  Skipping 0230-kth-smallest-element-in-a-bst.py: missing title or code
# ⚠️  Skipping 0231-power-of-two.py: missing title or code
# ⚠️  Skipping 0232-implement-queue-using-stacks.py: missing title or code
# ⚠️  Skipping 0234-palindrome-linked-list.py: missing title or code
# ⚠️  Skipping 0235-lowest-common-ancestor-of-a-binary-search-tree.py: missing title or code
# ⚠️  Skipping 0236-lowest-common-ancestor-of-a-binary-tree.py: missing title or code
# ⚠️  Skipping 0238-product-of-array-except-self.py: missing title or code
# ⚠️  Skipping 0239-sliding-window-maximum.py: missing title or code
# ⚠️  Skipping 0241-different-ways-to-add-parentheses.py: missing title or code
# ⚠️  Skipping 0242-valid-anagram.py: missing title or code
# ⚠️  Skipping 0252-meeting-rooms.py: missing title or code
# ⚠️  Skipping 0253-meeting-rooms-ii.py: missing title or code
# ⚠️  Skipping 0253-meeting-rooms.py: missing title or code
# ⚠️  Skipping 0261-graph-valid-tree.py: missing title or code
# ⚠️  Skipping 0263-ugly-number.py: missing title or code
# ⚠️  Skipping 0268-missing-number.py: missing title or code
# ⚠️  Skipping 0269-alien-dictionary.py: missing title or code
# ⚠️  Skipping 0271-encode-and-decode-strings.py: missing title or code
# ⚠️  Skipping 0274-H-index.py: missing title or code
# ⚠️  Skipping 0278-first-bad-version.py: missing title or code
# ⚠️  Skipping 0280-wiggle-sort.py: missing title or code
# ⚠️  Skipping 0283-move-zeroes.py: missing title or code
# ⚠️  Skipping 0286-walls-and-gates.py: missing title or code
# ⚠️  Skipping 0287-find-the-duplicate-number.py: missing title or code
# ⚠️  Skipping 0290-word-pattern.py: missing title or code
# ⚠️  Skipping 0295-find-median-from-data-stream.py: missing title or code
# ⚠️  Skipping 0297-serialize-and-deserialize-binary-tree.py: missing title or code
# ⚠️  Skipping 0300-longest-increasing-subsequence.py: missing title or code
# ⚠️  Skipping 0303-range-sum-query-immutable.py: missing title or code
# ⚠️  Skipping 0304-range-sum-query-2d-immutable.py: missing title or code
# ⚠️  Skipping 0309-best-time-to-buy-and-sell-stock-with-cooldown.py: missing title or code
# ⚠️  Skipping 0312-burst-balloons.py: missing title or code
# ⚠️  Skipping 0322-coin-change.py: missing title or code
# ⚠️  Skipping 0323-number-of-connected-components-in-an-undirected-graph.py: missing title or code
# ⚠️  Skipping 0329-longest-increasing-path-in-a-matrix.py: missing title or code
# ⚠️  Skipping 0332-reconstruct-itinerary.py: missing title or code
# ⚠️  Skipping 0334-increasing-triplet-subsequence.py: missing title or code
# ⚠️  Skipping 0338-counting-bits.py: missing title or code
# ⚠️  Skipping 0344-reverse-string.py: missing title or code
# ⚠️  Skipping 0347-top-k-frequent-elements.py: missing title or code
# ⚠️  Skipping 0349-intersection-of-two-arrays.py: missing title or code
# ⚠️  Skipping 0350-intersection-of-two-arrays-ii.py: missing title or code
# ⚠️  Skipping 0355-design-twitter.py: missing title or code
# ⚠️  Skipping 0367-valid-perfect-square.py: missing title or code
# ⚠️  Skipping 0371-sum-of-two-integers.py: missing title or code
# ⚠️  Skipping 0374-guess-number-higher-or-lower.py: missing title or code
# ⚠️  Skipping 0377-combination-sum-iv.py: missing title or code
# ⚠️  Skipping 0380-insert-delete-getrandom-o1.py: missing title or code
# ⚠️  Skipping 0383-ransom-note.py: missing title or code
# ⚠️  Skipping 0392-is-subsequence.py: missing title or code
# ⚠️  Skipping 0394-decode-string.py: missing title or code
# ⚠️  Skipping 0402-remove-k-digits.py: missing title or code
# ⚠️  Skipping 0410-split-array-largest-sum.py: missing title or code
# ⚠️  Skipping 0416-partition-equal-subset-sum.py: missing title or code
# ⚠️  Skipping 0417-pacific-atlantic-water-flow.py: missing title or code
# ⚠️  Skipping 0424-longest-repeating-character-replacement.py: missing title or code
# ⚠️  Skipping 0435-non-overlapping-intervals.py: missing title or code
# ⚠️  Skipping 0438-find-all-anagrams-in-a-string.py: missing title or code
# ⚠️  Skipping 0441-arranging-coins.py: missing title or code
# ⚠️  Skipping 0442-find-all-duplicates-in-an-array.py: missing title or code
# ⚠️  Skipping 0448-find-all-numbers-disappeared-in-an-array.py: missing title or code
# ⚠️  Skipping 0450-delete-node-in-a-bst.py: missing title or code
# ⚠️  Skipping 0452-minimum-number-of-arrows-to-burst-balloons.py: missing title or code
# ⚠️  Skipping 0456-132-pattern.py: missing title or code
# ⚠️  Skipping 0459-repeated-substring-pattern.py: missing title or code
# ⚠️  Skipping 0463-island-perimeter.py: missing title or code
# ⚠️  Skipping 0473-matchsticks-to-square.py: missing title or code
# ⚠️  Skipping 0474-ones-and-zeroes.py: missing title or code
# ⚠️  Skipping 0494-target-sum.py: missing title or code
# ⚠️  Skipping 0496-next-greater-element-i.py: missing title or code
# ⚠️  Skipping 0502-ipo.py: missing title or code
# ⚠️  Skipping 0509-fibonacci-number.py: missing title or code
# ⚠️  Skipping 0513-find-bottom-left-tree-value.py: missing title or code
# ⚠️  Skipping 0516-longest-palindromic-subsequence.py: missing title or code
# ⚠️  Skipping 0518-coin-change-ii.py: missing title or code
# ⚠️  Skipping 0523-continuous-subarray-sum.py: missing title or code
# ⚠️  Skipping 0525-contiguous-array.py: missing title or code
# ⚠️  Skipping 0535-encode-and-decode-tinyurl.py: missing title or code
# ⚠️  Skipping 0540-single-element-in-a-sorted-array.py: missing title or code
# ⚠️  Skipping 0543-diameter-of-binary-tree.py: missing title or code
# ⚠️  Skipping 0554-brick-wall.py: missing title or code
# ⚠️  Skipping 0560-subarray-sum-equals-k.py: missing title or code
# ⚠️  Skipping 0567-permutation-in-string.py: missing title or code
# ⚠️  Skipping 0572-subtree-of-another-tree.py: missing title or code
# ⚠️  Skipping 0605-can-place-flowers.py: missing title or code
# ⚠️  Skipping 0606-construct-string-from-binary-tree.py: missing title or code
# ⚠️  Skipping 0617-merge-two-binary-trees.py: missing title or code
# ⚠️  Skipping 0621-task-scheduler.py: missing title or code
# ⚠️  Skipping 0622-design-circular-queue.py: missing title or code
# ⚠️  Skipping 0647-palindromic-substrings.py: missing title or code
# ⚠️  Skipping 0658-find-k-closest-elements.py: missing title or code
# ⚠️  Skipping 0662-maximum-width-of-binary-tree.py: missing title or code
# ⚠️  Skipping 0665-non-decreasing-array.py: missing title or code
# ⚠️  Skipping 0669-trim-a-binary-search-tree.py: missing title or code
# ⚠️  Skipping 0673-number-of-longest-increasing-subsequence.py: missing title or code
# ⚠️  Skipping 0678-valid-parenthesis-string.py: missing title or code
# ⚠️  Skipping 0680-valid-palindrome-ii.py: missing title or code
# ⚠️  Skipping 0682-baseball-game.py: missing title or code
# ⚠️  Skipping 0684-redundant-connection.py: missing title or code
# ⚠️  Skipping 0695-max-area-of-island.py: missing title or code
# ⚠️  Skipping 0698-partition-to-k-equal-sum-subsets.py: missing title or code
# ⚠️  Skipping 0701-insert-into-a-binary-search-tree.py: missing title or code
# ⚠️  Skipping 0703-kth-largest-element-in-a-stream.py: missing title or code
# ⚠️  Skipping 0704-binary-search.py: missing title or code
# ⚠️  Skipping 0705-design-hashset.py: missing title or code
# ⚠️  Skipping 0706-design-hashmap.py: missing title or code
# ⚠️  Skipping 0707-design-linked-list.py: missing title or code
# ⚠️  Skipping 0721-accounts-merge.py: missing title or code
# ⚠️  Skipping 0724-find-pivot-index.py: missing title or code
# ⚠️  Skipping 0729-my-calendar-i.py: missing title or code
# ⚠️  Skipping 0735-asteroid-collision.py: missing title or code
# ⚠️  Skipping 0739-daily-temperatures.py: missing title or code
# ⚠️  Skipping 0740-delete-and-earn.py: missing title or code
# ⚠️  Skipping 0743-network-delay-time.py: missing title or code
# ⚠️  Skipping 0745-prefix-and-suffix-search.py: missing title or code
# ⚠️  Skipping 0746-min-cost-climbing-stairs.py: missing title or code
# ⚠️  Skipping 0752-open-the-lock.py: missing title or code
# ⚠️  Skipping 0763-partition-labels.py: missing title or code
# ⚠️  Skipping 0767-reorganize-string.py: missing title or code
# ⚠️  Skipping 0778-swim-in-rising-water.py: missing title or code
# ⚠️  Skipping 0783-minimum-distance-between-bst-nodes.py: missing title or code
# ⚠️  Skipping 0785-is-graph-bipartite.py: missing title or code
# ⚠️  Skipping 0787-cheapest-flights-within-k-stops.py: missing title or code
# ⚠️  Skipping 0791-custom-sort-string.py: missing title or code
# ⚠️  Skipping 0802-find-eventual-safe-states.py: missing title or code
# ⚠️  Skipping 0838-push-dominoes.py: missing title or code
# ⚠️  Skipping 0846-hand-of-straights.py: missing title or code
# ⚠️  Skipping 0853-car-fleet.py: missing title or code
# ⚠️  Skipping 0862-shortest-subarray-with-sum-at-least-k.py: missing title or code
# ⚠️  Skipping 0875-koko-eating-bananas.py: missing title or code
# ⚠️  Skipping 0876-middle-of-the-linked-list.py: missing title or code
# ⚠️  Skipping 0881-boats-to-save-people.py: missing title or code
# ⚠️  Skipping 0894-all-possible-full-binary-trees.py: missing title or code
# ⚠️  Skipping 0895-maximum-frequency-stack.py: missing title or code
# ⚠️  Skipping 0896-monotonic-array.py: missing title or code
# ⚠️  Skipping 0901-online-stock-span.py: missing title or code
# ⚠️  Skipping 0904-fruit-into-baskets.py: missing title or code
# ⚠️  Skipping 0904_fruit_into_baskets.py: missing title or code
# ⚠️  Skipping 0909-snakes-and-ladders.py: missing title or code
# ⚠️  Skipping 0912-sort-an-array.py: missing title or code
# ⚠️  Skipping 0918-maximum-sum-circular-subarray.py: missing title or code
# ⚠️  Skipping 0929-unique-email-addresses.py: missing title or code
# ⚠️  Skipping 0930-binary-subarrays-with-sum.py: missing title or code
# ⚠️  Skipping 0931-minimum-falling-path-sum.py: missing title or code
# ⚠️  Skipping 0946-validate-stack-sequences.py: missing title or code
# ⚠️  Skipping 0948-bag-of-tokens.py: missing title or code
# ⚠️  Skipping 0953-verifying-an-alien-dictionary.py: missing title or code
# ⚠️  Skipping 0973-k-closest-points-to-origin.py: missing title or code
# ⚠️  Skipping 0977-squares-of-a-sorted-array.py: missing title or code
# ⚠️  Skipping 0978-longest-turbulent-subarray.py: missing title or code
# ⚠️  Skipping 0981-time-based-key-value-store.py: missing title or code
# ⚠️  Skipping 0994-rotting-oranges.py: missing title or code
# ⚠️  Skipping 0997-find-the-town-judge.py: missing title or code
# ⚠️  Skipping 1011-capacity-to-ship-packages-within-d-days.py: missing title or code
# ⚠️  Skipping 1020-number-of-enclaves.py: missing title or code
# ⚠️  Skipping 1029-two-city-scheduling.py: missing title or code
# ⚠️  Skipping 1046-last-stone-weight.py: missing title or code
# ⚠️  Skipping 1049-last-stone-weight-ii.py: missing title or code
# ⚠️  Skipping 1074-number-of-submatrices-that-sum-to-target.py: missing title or code
# ⚠️  Skipping 1091-shortest-path-in-binary-matrix.py: missing title or code
# ⚠️  Skipping 1137-n-th-tribonacci-number.py: missing title or code
# ⚠️  Skipping 1143-longest-common-subsequence.py: missing title or code
# ⚠️  Skipping 1189-maximum-number-of-balloons.py: missing title or code
# ⚠️  Skipping 1203-sort-items-by-groups-respecting-dependencies.py: missing title or code
# ⚠️  Skipping 1209-remove-all-adjacent-duplicates-in-string-ii.py: missing title or code
# ⚠️  Skipping 1220-count-vowels-permutation.py: missing title or code
# ⚠️  Skipping 1239-maximum-length-of-a-concatenated-string-with-unique-characters.py: missing title or code
# ⚠️  Skipping 1254-number-of-closed-islands.py: missing title or code
# ⚠️  Skipping 1260-shift-2d-grid.py: missing title or code
# ⚠️  Skipping 1288-remove-covered-intervals.py: missing title or code
# ⚠️  Skipping 1299-replace-elements-with-greatest-element-on-right-side.py: missing title or code
# ⚠️  Skipping 1343-number-of-sub-arrays-of-size-k-and-average-greater-than-or-equal-to-threshold.py: missing title or code
# ⚠️  Skipping 1345-jump-game-iv.py: missing title or code
# ⚠️  Skipping 1383-maximum-performance-of-a-team.py: missing title or code
# ⚠️  Skipping 1396-design-underground-system.py: missing title or code
# ⚠️  Skipping 1397-find-all-good-strings.py: missing title or code
# ⚠️  Skipping 1423-maximum-points-you-can-obtain-from-cards.py: missing title or code
# ⚠️  Skipping 1448-count-good-nodes-in-binary-tree.py: missing title or code
# ⚠️  Skipping 1456-maximum-number-of-vowels-in-a-substring-of-given-length.py: missing title or code
# ⚠️  Skipping 1461-check-if-a-string-contains-all-binary-codes-of-size-k.py: missing title or code
# ⚠️  Skipping 1462-course-schedule-iv.py: missing title or code
# ⚠️  Skipping 1464-maximum-product-of-two-elements-in-an-array.py: missing title or code
# ⚠️  Skipping 1466-reorder-routes-to-make-all-paths-lead-to-the-city-zero.py: missing title or code
# ⚠️  Skipping 1472-design-browser-history.py: missing title or code
# ⚠️  Skipping 1475-final-prices-with-a-special-discount-in-a-shop.py: missing title or code
# ⚠️  Skipping 1481-least-number-of-unique-integers-after-k-removals.py: missing title or code
# ⚠️  Skipping 1489-find-critical-and-pseudo-critical-edges-in-minimum-spanning-tree.py: missing title or code
# ⚠️  Skipping 1498-number-of-subsequences-that-satisfy-the-given-sum-condition.py: missing title or code
# ⚠️  Skipping 1514-path-with-maximum-probability.py: missing title or code
# ⚠️  Skipping 1523-count-odd-numbers-in-an-interval-range.py: missing title or code
# ⚠️  Skipping 1572-matrix-diagonal-sum.py: missing title or code
# ⚠️  Skipping 1582-special-positions-in-a-binary-matrix.py: missing title or code
# ⚠️  Skipping 1584-min-cost-to-connect-all-points.py: missing title or code
# ⚠️  Skipping 1603-design-parking-system.py: missing title or code
# ⚠️  Skipping 1609-even-odd-tree.py: missing title or code
# ⚠️  Skipping 1631-path-with-minimum-effort.py: missing title or code
# ⚠️  Skipping 1642-furthest-building-you-can-reach.py: missing title or code
# ⚠️  Skipping 1658-minimum-operations-to-reduce-x-to-zero.py: missing title or code
# ⚠️  Skipping 1669-merge-in-between-linked-lists.py: missing title or code
# ⚠️  Skipping 1700-number-of-students-unable-to-eat-lunch.py: missing title or code
# ⚠️  Skipping 1721-swapping-nodes-in-a-linked-list.py: missing title or code
# ⚠️  Skipping 1750-minimum-length-of-string-after-deleting-similar-ends.py: missing title or code
# ⚠️  Skipping 1768-merge-strings-alternately.py: missing title or code
# ⚠️  Skipping 1800-maximum-ascending-subarray-sum.py: missing title or code
# ⚠️  Skipping 1822-sign-of-the-product-of-an-array.py: missing title or code
# ⚠️  Skipping 1834-single-threaded-cpu.py: missing title or code
# ⚠️  Skipping 1838-frequency-of-the-most-frequent-element.py: missing title or code
# ⚠️  Skipping 1845-seat-reservation-manager.py: missing title or code
# ⚠️  Skipping 1849-splitting-a-string-into-descending-consecutive-values.py: missing title or code
# ⚠️  Skipping 1851-minimum-interval-to-include-each-query.py: missing title or code
# ⚠️  Skipping 1888-minimum-number-of-flips-to-make-the-binary-string-alternating.py: missing title or code
# ⚠️  Skipping 1899-merge-triplets-to-form-target-triplet.py: missing title or code
# ⚠️  Skipping 1905-count-sub-islands.py: missing title or code
# ⚠️  Skipping 1929-concatenation-of-array.py: missing title or code
# ⚠️  Skipping 1930-unique-length-3-palindromic-subsequences.py: missing title or code
# ⚠️  Skipping 1958-check-if-move-is-legal.py: missing title or code
# ⚠️  Skipping 1963-minimum-number-of-swaps-to-make-the-string-balanced.py: missing title or code
# ⚠️  Skipping 1968-array-with-elements-not-equal-to-average-of-neighbors.py: missing title or code
# ⚠️  Skipping 1980-find-unique-binary-string.py: missing title or code
# ⚠️  Skipping 1984-minimum-difference-between-highest-and-lowest-of-k-scores.py: missing title or code
# ⚠️  Skipping 1985-find-the-kth-largest-integer-in-the-array.py: missing title or code
# ⚠️  Skipping 2001-number-of-pairs-of-interchangeable-rectangles.py: missing title or code
# ⚠️  Skipping 2002-maximum-product-of-the-length-of-two-palindromic-subsequences.py: missing title or code
# ⚠️  Skipping 2013-detect-squares.py: missing title or code
# ⚠️  Skipping 2017-grid-game.py: missing title or code
# ⚠️  Skipping 2092-find-all-people-with-secret.py: missing title or code
# ⚠️  Skipping 2101-detonate-the-maximum-bombs.py: missing title or code
# ⚠️  Skipping 2130-maximum-twin-sum-of-a-linked-list.py: missing title or code
# ⚠️  Skipping 2215-find-the-difference-of-two-arrays.py: missing title or code
# ⚠️  Skipping 2235-add-two-integers.py: missing title or code
# ⚠️  Skipping 2300-successful-pairs-of-spells-and-potions.py: missing title or code
# ⚠️  Skipping 2306-naming-a-company.py: missing title or code
# ⚠️  Skipping 2348-number-of-zero-filled-subarrays.py: missing title or code
# ⚠️  Skipping 2390-removing-stars-from-a-string.py: missing title or code
# ⚠️  Skipping 2402-meeting-rooms-iii.py: missing title or code
# ⚠️  Skipping 2405-optimal-partition-of-string.py: missing title or code
# ⚠️  Skipping 2482-difference-between-ones-and-zeros-in-row-and-column.py: missing title or code
# ⚠️  Skipping 2483-minimum-penalty-for-a-shop.py: missing title or code
# ⚠️  Skipping 2554-maximum-number-of-integers-to-choose-from-a-range-i.py: missing title or code
# ⚠️  Skipping 2616-minimize-the-maximum-difference-of-pairs.py: missing title or code
# ⚠️  Skipping 2709-greatest-common-divisor-traversal.py: missing title or code
# ⚠️  Skipping 2864-maximum-odd-binary-number.py: missing title or code
# ⚠️  Skipping 2971-find-polygon-with-the-largest-perimeter.py: missing title or code
# ✅ Converted 0 problems → neetcode_problems.json

# %%
import os
import json
import re
import sys

def extract_fields_from_py(filepath):
    """
    Read a .py file and extract:
      - title, description, time/space complexities, tags from leading comments
      - the rest of the file as optimal_code
    Fallbacks:
      - Title inferred from filename if missing
      - description → "No description available."
      - complexities → "Unknown"
      - tags → []
    """
    title = description = time = space = ""
    tags = []
    code_lines = []

    with open(filepath, 'r', encoding='utf-8') as f:
        for raw in f:
            line = raw.rstrip('\n')
            if line.lstrip().startswith('#'):
                meta = line.lstrip()[1:].strip()
                # metadata keys (case-insensitive)
                if meta.lower().startswith('title:'):
                    title = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('description:'):
                    description = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('time complexity:'):
                    time = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('space complexity:'):
                    space = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('tags:'):
                    tags = [t.strip() for t in meta.split(':', 1)[1].split(',')]
                # else: ignore other comments
            else:
                code_lines.append(raw)

    # Fallback: infer title from filename if not provided
    if not title:
        fname = os.path.basename(filepath)
        name = os.path.splitext(fname)[0]
        # strip any leading numbers and hyphens
        name = re.sub(r'^\d+[-_]*', '', name)
        title = name.replace('_', ' ').replace('-', ' ').title()

    return {
        "title": title,
        "description": description or "No description available.",
        "optimal_code": "".join(code_lines).rstrip(),
        "time_complexity": time or "Unknown",
        "space_complexity": space or "Unknown",
        "tags": tags
    }

def convert_all_py_to_json(src_dir, output_path):
    """
    Walk src_dir recursively, convert every .py file to a JSON entry,
    and write the list out to output_path.
    """
    if not os.path.isdir(src_dir):
        raise ValueError(f"Source directory not found: {src_dir}")

    # ensure the output directory exists
    out_dir = os.path.dirname(output_path)
    if out_dir:
        os.makedirs(out_dir, exist_ok=True)

    problems = []
    for root, _, files in os.walk(src_dir):
        for fname in sorted(files):
            if not fname.lower().endswith('.py') or fname == "__init__.py":
                continue
            full_path = os.path.join(root, fname)
            try:
                entry = extract_fields_from_py(full_path)
                # skip if code is empty
                if entry["optimal_code"].strip():
                    problems.append(entry)
                else:
                    print(f"⚠️  Skipping {full_path}: no code detected")
            except Exception as e:
                print(f"❌ Error processing {full_path}: {e}")

    # write JSON
    with open(output_path, 'w', encoding='utf-8') as out_f:
        json.dump(problems, out_f, indent=2, ensure_ascii=False)

    print(f"✅ Converted {len(problems)} problems → {output_path}")


# ----------------------
# If run as a script, accept command-line args
if __name__ == "__main__":
    if len(sys.argv) >= 3:
        src = sys.argv[1]
        dest = sys.argv[2]
    else:
        # defaults: adjust as needed
        src = "npy/leetcode/python"
        dest = "neetcode_problems.json"

    convert_all_py_to_json(src, dest)
# Out:
# ✅ Converted 396 problems → neetcode_problems.json

# %%
import os
import json
import re
import sys

def infer_complexity_and_tags(code: str):
    """
    Infer time and space complexities + relevant tags from code heuristically.
    """
    tags = set()
    time_complexity = "Unknown"
    space_complexity = "Unknown"

    code_lower = code.lower()

    # Tag inference
    if "dict" in code_lower or "{}" in code_lower:
        tags.add("hash table")
        space_complexity = "O(n)"
    if "set" in code_lower:
        tags.add("hash table")
        space_complexity = "O(n)"
    if "while" in code_lower and "l < r" in code_lower:
        tags.update(["two pointers", "sliding window"])
        time_complexity = "O(n)"
    if "for" in code_lower and "range(len" in code_lower:
        tags.add("array")
    if "if len(" in code_lower and ">" in code_lower and "binary search" not in tags:
        tags.add("binary search")
        time_complexity = "O(log n)"
    if "listnode" in code_lower:
        tags.add("linked list")
    if "treenode" in code_lower:
        tags.add("tree")
    if "dfs" in code_lower or "recurse" in code_lower:
        tags.update(["recursion", "dfs"])
    if "math." in code_lower or "%" in code_lower or "//" in code_lower:
        tags.add("math")
    if "dp" in code_lower or "[i][j]" in code_lower:
        tags.add("dynamic programming")

    # Time complexity estimation
    if time_complexity == "Unknown":
        if "for" in code_lower and "for" in code_lower.split("for", 1)[-1]:
            time_complexity = "O(n^2)"
        elif "for" in code_lower:
            time_complexity = "O(n)"
        elif "while" in code_lower and "l < r" in code_lower:
            time_complexity = "O(n)"
        elif "binary search" in tags:
            time_complexity = "O(log n)"

    if space_complexity == "Unknown":
        if "res =" in code_lower or "result =" in code_lower:
            space_complexity = "O(n)"
        elif "return" in code_lower:
            space_complexity = "O(1)"

    return time_complexity, space_complexity, sorted(tags)

def extract_fields_from_py(filepath):
    """
    Read a .py file and extract metadata + code.
    If complexity/tags are missing from comments, infer them heuristically.
    """
    title = description = time = space = ""
    tags = []
    code_lines = []

    with open(filepath, 'r', encoding='utf-8') as f:
        for raw in f:
            line = raw.rstrip('\n')
            if line.lstrip().startswith('#'):
                meta = line.lstrip()[1:].strip()
                if meta.lower().startswith('title:'):
                    title = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('description:'):
                    description = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('time complexity:'):
                    time = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('space complexity:'):
                    space = meta.split(':', 1)[1].strip()
                elif meta.lower().startswith('tags:'):
                    tags = [t.strip() for t in meta.split(':', 1)[1].split(',')]
            else:
                code_lines.append(raw)

    if not title:
        fname = os.path.basename(filepath)
        name = os.path.splitext(fname)[0]
        name = re.sub(r'^\d+[-_]*', '', name)
        title = name.replace('_', ' ').replace('-', ' ').title()

    code = "".join(code_lines).rstrip()

    # Infer missing values
    inferred_time, inferred_space, inferred_tags = infer_complexity_and_tags(code)
    time = time or inferred_time
    space = space or inferred_space
    tags = tags or inferred_tags

    return {
        "title": title,
        "description": description or "No description available.",
        "optimal_code": code,
        "time_complexity": time,
        "space_complexity": space,
        "tags": tags
    }

def convert_all_py_to_json(src_dir, output_path):
    """
    Walk src_dir recursively, convert every .py file to a JSON entry,
    and write the list out to output_path.
    """
    if not os.path.isdir(src_dir):
        raise ValueError(f"Source directory not found: {src_dir}")

    out_dir = os.path.dirname(output_path)
    if out_dir:
        os.makedirs(out_dir, exist_ok=True)

    problems = []
    for root, _, files in os.walk(src_dir):
        for fname in sorted(files):
            if not fname.lower().endswith('.py') or fname == "__init__.py":
                continue
            full_path = os.path.join(root, fname)
            try:
                entry = extract_fields_from_py(full_path)
                if entry["optimal_code"].strip():
                    problems.append(entry)
                else:
                    print(f"⚠️  Skipping {full_path}: no code detected")
            except Exception as e:
                print(f"❌ Error processing {full_path}: {e}")

    with open(output_path, 'w', encoding='utf-8') as out_f:
        json.dump(problems, out_f, indent=2, ensure_ascii=False)

    print(f"✅ Converted {len(problems)} problems → {output_path}")

if __name__ == "__main__":
    if len(sys.argv) >= 3:
        src = sys.argv[1]
        dest = sys.argv[2]
    else:
        src = "npy/leetcode/python"
        dest = "neetcode_problems.json"

    convert_all_py_to_json(src, dest)
# Out:
# ✅ Converted 396 problems → neetcode_problems.json

# %%
import json
import numpy as np
import faiss
import subprocess

# Load your dataset
with open("neetcode_problems.json", "r", encoding="utf-8") as f:
    problems = json.load(f)

# Prepare input texts (title + description + code)
texts = [f"{p['title']}. {p['description']} {p['optimal_code']}" for p in problems]

def get_embedding_ollama(text: str):
    prompt = {
        "model": "nomic-embed-text",
        "prompt": text
    }
    result = subprocess.run(
        ["C:/Users/prana/AppData/Local/Programs/Ollama/ollama.exe", "embeddings", "--model", "nomic-embed-text"],
        input=json.dumps(prompt),
        capture_output=True,
        text=True
    )
    response = json.loads(result.stdout)
    return np.array(response["embedding"], dtype="float32")

# Generate and collect all embeddings
embeddings = np.array([get_embedding_ollama(text) for text in texts], dtype="float32")

# Create and save FAISS index
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(embeddings)
faiss.write_index(index, "rag_nomic_index.faiss")

# Save problems alongside index
with open("rag_nomic_problems.json", "w", encoding="utf-8") as f:
    json.dump(problems, f, indent=2)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 28
#      25     return np.array(response["embedding"], dtype="float32")
#      27 # Generate and collect all embeddings
# ---> 28 embeddings = np.array([get_embedding_ollama(text) for text in texts], dtype="float32")
#      30 # Create and save FAISS index
#      31 dim = embeddings.shape[1]
#
# Cell In[10], line 24, in get_embedding_ollama(text)
#      14 prompt = {
#      15     "model": "nomic-embed-text",
#      16     "prompt": text
#      17 }
#      18 result = subprocess.run(
#      19     ["C:/Users/prana/AppData/Local/Programs/Ollama/ollama.exe", "embeddings", "--model", "nomic-embed-text"],
#      20     input=json.dumps(prompt),
#      21     capture_output=True,
#      22     text=True
#      23 )
# ---> 24 response = json.loads(result.stdout)
#      25 return np.array(response["embedding"], dtype="float32")
#
# File c:\Users\prana\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\prana\anaconda3\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\prana\anaconda3\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import json
import numpy as np
import faiss
import subprocess
import time

# Load your dataset
with open("neetcode_problems.json", "r", encoding="utf-8") as f:
    problems = json.load(f)

# Prepare input texts (title + description + code)
texts = [f"{p['title']}. {p['description']} {p['optimal_code']}" for p in problems]

def get_embedding_ollama(text: str):
    prompt = {
        "model": "nomic-embed-text",
        "prompt": text
    }
    try:
        result = subprocess.run(
            ["C:/Users/prana/AppData/Local/Programs/Ollama/ollama.exe", "embeddings", "--model", "nomic-embed-text"],
            input=json.dumps(prompt),
            capture_output=True,
            text=True,
            timeout=20  # seconds
        )
        if result.returncode != 0:
            raise RuntimeError(f"Ollama failed: {result.stderr}")
        response = json.loads(result.stdout)
        return np.array(response["embedding"], dtype="float32")
    except Exception as e:
        print(f"❌ Error embedding text: {text[:50]}... \n{e}")
        return None

# Generate and collect all embeddings
valid_problems = []
all_embeddings = []

for i, text in enumerate(texts):
    print(f"🔎 Embedding problem {i + 1}/{len(texts)}: {problems[i]['title']}")
    emb = get_embedding_ollama(text)
    if emb is not None:
        all_embeddings.append(emb)
        valid_problems.append(problems[i])
    else:
        print(f"⚠️ Skipping: {problems[i]['title']}")
    time.sleep(0.1)  # Be kind to system load

embeddings = np.vstack(all_embeddings).astype("float32")

# Create and save FAISS index
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(embeddings)
faiss.write_index(index, "rag_nomic_index.faiss")

# Save only the successfully embedded problems
with open("rag_nomic_problems.json", "w", encoding="utf-8") as f:
    json.dump(valid_problems, f, indent=2)

print(f"✅ Index built for {len(valid_problems)} problems and saved successfully.")
# Out:
# 🔎 Embedding problem 1/396: Two Sum
# ❌ Error embedding text: Two Sum. No description available. class Solution:...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Two Sum
# 🔎 Embedding problem 2/396: Add Two Numbers
# ❌ Error embedding text: Add Two Numbers. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Add Two Numbers
# 🔎 Embedding problem 3/396: Longest Substring Without Repeating Characters
# ❌ Error embedding text: Longest Substring Without Repeating Characters. No...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Substring Without Repeating Characters
# 🔎 Embedding problem 4/396: Median Of Two Sorted Arrays
# ❌ Error embedding text: Median Of Two Sorted Arrays. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Median Of Two Sorted Arrays
# 🔎 Embedding problem 5/396: Longest Palindromic Substring
# ❌ Error embedding text: Longest Palindromic Substring. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Palindromic Substring
# 🔎 Embedding problem 6/396: Zigzag Conversion
# ❌ Error embedding text: Zigzag Conversion. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Zigzag Conversion
# 🔎 Embedding problem 7/396: Reverse Integer
# ❌ Error embedding text: Reverse Integer. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Integer
# 🔎 Embedding problem 8/396: Palindrome Number
# ❌ Error embedding text: Palindrome Number. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Palindrome Number
# 🔎 Embedding problem 9/396: Regular Expression Matching
# ❌ Error embedding text: Regular Expression Matching. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Regular Expression Matching
# 🔎 Embedding problem 10/396: Container With Most Water
# ❌ Error embedding text: Container With Most Water. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Container With Most Water
# 🔎 Embedding problem 11/396: Integer To Roman
# ❌ Error embedding text: Integer To Roman. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Integer To Roman
# 🔎 Embedding problem 12/396: Roman To Integer
# ❌ Error embedding text: Roman To Integer. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Roman To Integer
# 🔎 Embedding problem 13/396: Longest Common Prefix
# ❌ Error embedding text: Longest Common Prefix. No description available. c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Common Prefix
# 🔎 Embedding problem 14/396: 3Sum
# ❌ Error embedding text: 3Sum. No description available. class Solution:
#   ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: 3Sum
# 🔎 Embedding problem 15/396: 3Sum Closest
# ❌ Error embedding text: 3Sum Closest. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: 3Sum Closest
# 🔎 Embedding problem 16/396: Letter Combinations Of A Phone Number
# ❌ Error embedding text: Letter Combinations Of A Phone Number. No descript...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Letter Combinations Of A Phone Number
# 🔎 Embedding problem 17/396: 4Sum
# ❌ Error embedding text: 4Sum. No description available. class Solution:
#   ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: 4Sum
# 🔎 Embedding problem 18/396: Remove Nth Node From End Of List
# ❌ Error embedding text: Remove Nth Node From End Of List. No description a...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Nth Node From End Of List
# 🔎 Embedding problem 19/396: Valid Parentheses
# ❌ Error embedding text: Valid Parentheses. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Valid Parentheses
# 🔎 Embedding problem 20/396: Merge Two Sorted Lists
# ❌ Error embedding text: Merge Two Sorted Lists. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge Two Sorted Lists
# 🔎 Embedding problem 21/396: Generate Parentheses
# ❌ Error embedding text: Generate Parentheses. No description available. cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Generate Parentheses
# 🔎 Embedding problem 22/396: Merge K Sorted Lists
# ❌ Error embedding text: Merge K Sorted Lists. No description available. cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge K Sorted Lists
# 🔎 Embedding problem 23/396: Swap Nodes In Pairs
# ❌ Error embedding text: Swap Nodes In Pairs. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Swap Nodes In Pairs
# 🔎 Embedding problem 24/396: Reverse Nodes In K Group
# ❌ Error embedding text: Reverse Nodes In K Group. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Nodes In K Group
# 🔎 Embedding problem 25/396: Remove Duplicates From Sorted Array
# ❌ Error embedding text: Remove Duplicates From Sorted Array. No descriptio...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Duplicates From Sorted Array
# 🔎 Embedding problem 26/396: Remove Element
# ❌ Error embedding text: Remove Element. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Element
# 🔎 Embedding problem 27/396: Find The Index Of The First Occurrence In A String
# ❌ Error embedding text: Find The Index Of The First Occurrence In A String...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find The Index Of The First Occurrence In A String
# 🔎 Embedding problem 28/396: Search In Rotated Sorted Array
# ❌ Error embedding text: Search In Rotated Sorted Array. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Search In Rotated Sorted Array
# 🔎 Embedding problem 29/396: Find First And Last Position Of Element In Sorted Array
# ❌ Error embedding text: Find First And Last Position Of Element In Sorted ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find First And Last Position Of Element In Sorted Array
# 🔎 Embedding problem 30/396: Search Insert Position
# ❌ Error embedding text: Search Insert Position. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Search Insert Position
# 🔎 Embedding problem 31/396: Valid Sudoku
# ❌ Error embedding text: Valid Sudoku. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Valid Sudoku
# 🔎 Embedding problem 32/396: Combination Sum
# ❌ Error embedding text: Combination Sum. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Combination Sum
# 🔎 Embedding problem 33/396: Combination Sum Ii
# ❌ Error embedding text: Combination Sum Ii. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Combination Sum Ii
# 🔎 Embedding problem 34/396: First Missing Positive
# ❌ Error embedding text: First Missing Positive. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: First Missing Positive
# 🔎 Embedding problem 35/396: Trapping Rain Water
# ❌ Error embedding text: Trapping Rain Water. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Trapping Rain Water
# 🔎 Embedding problem 36/396: Multiply Strings
# ❌ Error embedding text: Multiply Strings. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Multiply Strings
# 🔎 Embedding problem 37/396: Wildcard Matching
# ❌ Error embedding text: Wildcard Matching. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Wildcard Matching
# 🔎 Embedding problem 38/396: Jump Game Ii
# ❌ Error embedding text: Jump Game Ii. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Jump Game Ii
# 🔎 Embedding problem 39/396: Permutations
# ❌ Error embedding text: Permutations. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Permutations
# 🔎 Embedding problem 40/396: Permutations Ii
# ❌ Error embedding text: Permutations Ii. No description available. import ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Permutations Ii
# 🔎 Embedding problem 41/396: Rotate Image
# ❌ Error embedding text: Rotate Image. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Rotate Image
# 🔎 Embedding problem 42/396: Group Anagrams
# ❌ Error embedding text: Group Anagrams. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Group Anagrams
# 🔎 Embedding problem 43/396: Powx N
# ❌ Error embedding text: Powx N. No description available. class Solution:
# ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Powx N
# 🔎 Embedding problem 44/396: N Queens
# ❌ Error embedding text: N Queens. No description available. class Solution...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: N Queens
# 🔎 Embedding problem 45/396: N Queens Ii
# ❌ Error embedding text: N Queens Ii. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: N Queens Ii
# 🔎 Embedding problem 46/396: Maximum Subarray
# ❌ Error embedding text: Maximum Subarray. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Subarray
# 🔎 Embedding problem 47/396: Spiral Matrix
# ❌ Error embedding text: Spiral Matrix. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Spiral Matrix
# 🔎 Embedding problem 48/396: Jump Game
# ❌ Error embedding text: Jump Game. No description available. class Solutio...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Jump Game
# 🔎 Embedding problem 49/396: Merge Intervals
# ❌ Error embedding text: Merge Intervals. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge Intervals
# 🔎 Embedding problem 50/396: Insert Interval
# ❌ Error embedding text: Insert Interval. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Insert Interval
# 🔎 Embedding problem 51/396: Length Of Last Word
# ❌ Error embedding text: Length Of Last Word. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Length Of Last Word
# 🔎 Embedding problem 52/396: Rotate List
# ❌ Error embedding text: Rotate List. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Rotate List
# 🔎 Embedding problem 53/396: Unique Paths
# ❌ Error embedding text: Unique Paths. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Unique Paths
# 🔎 Embedding problem 54/396: Unique Paths Ii
# ❌ Error embedding text: Unique Paths Ii. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Unique Paths Ii
# 🔎 Embedding problem 55/396: Minimum Path Sum
# ❌ Error embedding text: Minimum Path Sum. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Path Sum
# 🔎 Embedding problem 56/396: Plus One
# ❌ Error embedding text: Plus One. No description available. class Solution...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Plus One
# 🔎 Embedding problem 57/396: Add Binary
# ❌ Error embedding text: Add Binary. No description available. class Soluti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Add Binary
# 🔎 Embedding problem 58/396: Text Justification
# ❌ Error embedding text: Text Justification. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Text Justification
# 🔎 Embedding problem 59/396: Sqrtx
# ❌ Error embedding text: Sqrtx. No description available. class Solution:
#  ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sqrtx
# 🔎 Embedding problem 60/396: Climbing Stairs
# ❌ Error embedding text: Climbing Stairs. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Climbing Stairs
# 🔎 Embedding problem 61/396: Simplify Path
# ❌ Error embedding text: Simplify Path. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Simplify Path
# 🔎 Embedding problem 62/396: Edit Distance
# ❌ Error embedding text: Edit Distance. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Edit Distance
# 🔎 Embedding problem 63/396: Set Matrix Zeroes
# ❌ Error embedding text: Set Matrix Zeroes. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Set Matrix Zeroes
# 🔎 Embedding problem 64/396: Search A 2D Matrix
# ❌ Error embedding text: Search A 2D Matrix. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Search A 2D Matrix
# 🔎 Embedding problem 65/396: Sort Colors
# ❌ Error embedding text: Sort Colors. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sort Colors
# 🔎 Embedding problem 66/396: Minimum Window Substring
# ❌ Error embedding text: Minimum Window Substring. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Window Substring
# 🔎 Embedding problem 67/396: Combinations
# ❌ Error embedding text: Combinations. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Combinations
# 🔎 Embedding problem 68/396: Subsets
# ❌ Error embedding text: Subsets. No description available. class Solution:...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Subsets
# 🔎 Embedding problem 69/396: Word Search
# ❌ Error embedding text: Word Search. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Word Search
# 🔎 Embedding problem 70/396: Remove Duplicates From Sorted Array Ii
# ❌ Error embedding text: Remove Duplicates From Sorted Array Ii. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Duplicates From Sorted Array Ii
# 🔎 Embedding problem 71/396: Search In Rotated Sorted Array Ii
# ❌ Error embedding text: Search In Rotated Sorted Array Ii. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Search In Rotated Sorted Array Ii
# 🔎 Embedding problem 72/396: Remove Duplicates From Sorted List
# ❌ Error embedding text: Remove Duplicates From Sorted List. No description...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Duplicates From Sorted List
# 🔎 Embedding problem 73/396: Largest Rectangle In Histogram
# ❌ Error embedding text: Largest Rectangle In Histogram. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Largest Rectangle In Histogram
# 🔎 Embedding problem 74/396: Partition List
# ❌ Error embedding text: Partition List. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Partition List
# 🔎 Embedding problem 75/396: Merge Sorted Array
# ❌ Error embedding text: Merge Sorted Array. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge Sorted Array
# 🔎 Embedding problem 76/396: Subsets Ii
# ❌ Error embedding text: Subsets Ii. No description available. class Soluti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Subsets Ii
# 🔎 Embedding problem 77/396: Decode Ways
# ❌ Error embedding text: Decode Ways. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Decode Ways
# 🔎 Embedding problem 78/396: Reverse Linked List Ii
# ❌ Error embedding text: Reverse Linked List Ii. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Linked List Ii
# 🔎 Embedding problem 79/396: Binary Tree Inorder Traversal
# ❌ Error embedding text: Binary Tree Inorder Traversal. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Inorder Traversal
# 🔎 Embedding problem 80/396: Interleaving String
# ❌ Error embedding text: Interleaving String. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Interleaving String
# 🔎 Embedding problem 81/396: Validate Binary Search Tree
# ❌ Error embedding text: Validate Binary Search Tree. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Validate Binary Search Tree
# 🔎 Embedding problem 82/396: Same Tree
# ❌ Error embedding text: Same Tree. No description available.
#
# class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Same Tree
# 🔎 Embedding problem 83/396: Symmetric Tree
# ❌ Error embedding text: Symmetric Tree. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Symmetric Tree
# 🔎 Embedding problem 84/396: Binary Tree Level Order Traversal
# ❌ Error embedding text: Binary Tree Level Order Traversal. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Level Order Traversal
# 🔎 Embedding problem 85/396: Binary Tree Zigzag Level Order Traversal
# ❌ Error embedding text: Binary Tree Zigzag Level Order Traversal. No descr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Zigzag Level Order Traversal
# 🔎 Embedding problem 86/396: Maximum Depth Of Binary Tree
# ❌ Error embedding text: Maximum Depth Of Binary Tree. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Depth Of Binary Tree
# 🔎 Embedding problem 87/396: Construct Binary Tree From Preorder And Inorder Traversal
# ❌ Error embedding text: Construct Binary Tree From Preorder And Inorder Tr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Construct Binary Tree From Preorder And Inorder Traversal
# 🔎 Embedding problem 88/396: Construct Binary Tree From Inorder And Postorder Traversal
# ❌ Error embedding text: Construct Binary Tree From Inorder And Postorder T...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Construct Binary Tree From Inorder And Postorder Traversal
# 🔎 Embedding problem 89/396: Convert Sorted Array To Binary Search Tree
# ❌ Error embedding text: Convert Sorted Array To Binary Search Tree. No des...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Convert Sorted Array To Binary Search Tree
# 🔎 Embedding problem 90/396: Balanced Binary Tree
# ❌ Error embedding text: Balanced Binary Tree. No description available. cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Balanced Binary Tree
# 🔎 Embedding problem 91/396: Path Sum
# ❌ Error embedding text: Path Sum. No description available. class Solution...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Path Sum
# 🔎 Embedding problem 92/396: Distinct Subsequences
# ❌ Error embedding text: Distinct Subsequences. No description available. c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Distinct Subsequences
# 🔎 Embedding problem 93/396: Pascals Triangle
# ❌ Error embedding text: Pascals Triangle. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Pascals Triangle
# 🔎 Embedding problem 94/396: Pascal Triangle Ii
# ❌ Error embedding text: Pascal Triangle Ii. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Pascal Triangle Ii
# 🔎 Embedding problem 95/396: Triangle
# ❌ Error embedding text: Triangle. No description available. class Solution...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Triangle
# 🔎 Embedding problem 96/396: Best Time To Buy And Sell Stock
# ❌ Error embedding text: Best Time To Buy And Sell Stock. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Best Time To Buy And Sell Stock
# 🔎 Embedding problem 97/396: Best Time To Buy And Sell Stock Ii
# ❌ Error embedding text: Best Time To Buy And Sell Stock Ii. No description...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Best Time To Buy And Sell Stock Ii
# 🔎 Embedding problem 98/396: Binary Tree Maximum Path Sum
# ❌ Error embedding text: Binary Tree Maximum Path Sum. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Maximum Path Sum
# 🔎 Embedding problem 99/396: Valid Palindrome
# ❌ Error embedding text: Valid Palindrome. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Valid Palindrome
# 🔎 Embedding problem 100/396: Word Ladder
# ❌ Error embedding text: Word Ladder. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Word Ladder
# 🔎 Embedding problem 101/396: Longest Consecutive Sequence
# ❌ Error embedding text: Longest Consecutive Sequence. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Consecutive Sequence
# 🔎 Embedding problem 102/396: Surrounded Regions
# ❌ Error embedding text: Surrounded Regions. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Surrounded Regions
# 🔎 Embedding problem 103/396: Palindrome Partitioning
# ❌ Error embedding text: Palindrome Partitioning. No description available....
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Palindrome Partitioning
# 🔎 Embedding problem 104/396: Clone Graph
# ❌ Error embedding text: Clone Graph. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Clone Graph
# 🔎 Embedding problem 105/396: Gas Station
# ❌ Error embedding text: Gas Station. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Gas Station
# 🔎 Embedding problem 106/396: Candy
# ❌ Error embedding text: Candy. No description available. class Solution:
#  ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Candy
# 🔎 Embedding problem 107/396: Single Number
# ❌ Error embedding text: Single Number. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Single Number
# 🔎 Embedding problem 108/396: Copy List With Random Pointer
# ❌ Error embedding text: Copy List With Random Pointer. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Copy List With Random Pointer
# 🔎 Embedding problem 109/396: Word Break
# ❌ Error embedding text: Word Break. No description available. class Soluti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Word Break
# 🔎 Embedding problem 110/396: Linked List Cycle
# ❌ Error embedding text: Linked List Cycle. No description available.
#
# cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Linked List Cycle
# 🔎 Embedding problem 111/396: Reorder List
# ❌ Error embedding text: Reorder List. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reorder List
# 🔎 Embedding problem 112/396: Binary Tree Preorder Traversal
# ❌ Error embedding text: Binary Tree Preorder Traversal. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Preorder Traversal
# 🔎 Embedding problem 113/396: Binary Tree Postorder Traversal
# ❌ Error embedding text: Binary Tree Postorder Traversal. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Postorder Traversal
# 🔎 Embedding problem 114/396: Lru Cache
# ❌ Error embedding text: Lru Cache. No description available. class Node:
#  ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Lru Cache
# 🔎 Embedding problem 115/396: Insertion Sort List
# ❌ Error embedding text: Insertion Sort List. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Insertion Sort List
# 🔎 Embedding problem 116/396: Sort List
# ❌ Error embedding text: Sort List. No description available. class Solutio...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sort List
# 🔎 Embedding problem 117/396: Max Points On A Line
# ❌ Error embedding text: Max Points On A Line. No description available. cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Max Points On A Line
# 🔎 Embedding problem 118/396: Evaluate Reverse Polish Notation
# ❌ Error embedding text: Evaluate Reverse Polish Notation. No description a...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Evaluate Reverse Polish Notation
# 🔎 Embedding problem 119/396: Reverse Words In A String
# ❌ Error embedding text: Reverse Words In A String. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Words In A String
# 🔎 Embedding problem 120/396: Maximum Product Subarray
# ❌ Error embedding text: Maximum Product Subarray. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Product Subarray
# 🔎 Embedding problem 121/396: Find Minimum In Rotated Sorted Array
# ❌ Error embedding text: Find Minimum In Rotated Sorted Array. No descripti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Minimum In Rotated Sorted Array
# 🔎 Embedding problem 122/396: Min Stack
# ❌ Error embedding text: Min Stack. No description available. class MinStac...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Min Stack
# 🔎 Embedding problem 123/396: Intersection Of Two Linked Lists
# ❌ Error embedding text: Intersection Of Two Linked Lists. No description a...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Intersection Of Two Linked Lists
# 🔎 Embedding problem 124/396: Find Peak Element
# ❌ Error embedding text: Find Peak Element. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Peak Element
# 🔎 Embedding problem 125/396: Two Sum Ii Input Array Is Sorted
# ❌ Error embedding text: Two Sum Ii Input Array Is Sorted. No description a...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Two Sum Ii Input Array Is Sorted
# 🔎 Embedding problem 126/396: Excel Sheet Column Title
# ❌ Error embedding text: Excel Sheet Column Title. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Excel Sheet Column Title
# 🔎 Embedding problem 127/396: Majority Element
# ❌ Error embedding text: Majority Element. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Majority Element
# 🔎 Embedding problem 128/396: Largest Number
# ❌ Error embedding text: Largest Number. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Largest Number
# 🔎 Embedding problem 129/396: Repeated Dna Sequences
# ❌ Error embedding text: Repeated Dna Sequences. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Repeated Dna Sequences
# 🔎 Embedding problem 130/396: Rotate Array
# ❌ Error embedding text: Rotate Array. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Rotate Array
# 🔎 Embedding problem 131/396: Reverse Bits
# ❌ Error embedding text: Reverse Bits. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Bits
# 🔎 Embedding problem 132/396: Number Of 1 Bits
# ❌ Error embedding text: Number Of 1 Bits. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of 1 Bits
# 🔎 Embedding problem 133/396: House Robber
# ❌ Error embedding text: House Robber. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: House Robber
# 🔎 Embedding problem 134/396: Binary Tree Right Side View
# ❌ Error embedding text: Binary Tree Right Side View. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Binary Tree Right Side View
# 🔎 Embedding problem 135/396: Number Of Islands
# ❌ Error embedding text: Number Of Islands. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Islands
# 🔎 Embedding problem 136/396: Bitwise And Of Numbers Range
# ❌ Error embedding text: Bitwise And Of Numbers Range. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Bitwise And Of Numbers Range
# 🔎 Embedding problem 137/396: Happy Number
# ❌ Error embedding text: Happy Number. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Happy Number
# 🔎 Embedding problem 138/396: Remove Linked List Elements
# ❌ Error embedding text: Remove Linked List Elements. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove Linked List Elements
# 🔎 Embedding problem 139/396: Isomorphic Strings
# ❌ Error embedding text: Isomorphic Strings. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Isomorphic Strings
# 🔎 Embedding problem 140/396: Reverse Linked List
# ❌ Error embedding text: Reverse Linked List. No description available.
#
# c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse Linked List
# 🔎 Embedding problem 141/396: Course Schedule
# ❌ Error embedding text: Course Schedule. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Course Schedule
# 🔎 Embedding problem 142/396: Implement Trie Prefix Tree
# ❌ Error embedding text: Implement Trie Prefix Tree. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Implement Trie Prefix Tree
# 🔎 Embedding problem 143/396: Minimum Size Subarray Sum
# ❌ Error embedding text: Minimum Size Subarray Sum. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Size Subarray Sum
# 🔎 Embedding problem 144/396: Course Schedule Ii
# ❌ Error embedding text: Course Schedule Ii. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Course Schedule Ii
# 🔎 Embedding problem 145/396: Design Add And Search Words Data Structure
# ❌ Error embedding text: Design Add And Search Words Data Structure. No des...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Design Add And Search Words Data Structure
# 🔎 Embedding problem 146/396: Word Search Ii
# ❌ Error embedding text: Word Search Ii. No description available. class Tr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Word Search Ii
# 🔎 Embedding problem 147/396: House Robber Ii
# ❌ Error embedding text: House Robber Ii. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: House Robber Ii
# 🔎 Embedding problem 148/396: Kth Largest Element In An Array
# ❌ Error embedding text: Kth Largest Element In An Array. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Kth Largest Element In An Array
# 🔎 Embedding problem 149/396: Contains Duplicate
# ❌ Error embedding text: Contains Duplicate. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Contains Duplicate
# 🔎 Embedding problem 150/396: Contains Duplicate Ii
# ❌ Error embedding text: Contains Duplicate Ii. No description available. c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Contains Duplicate Ii
# 🔎 Embedding problem 151/396: Maximal Square
# ❌ Error embedding text: Maximal Square. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximal Square
# 🔎 Embedding problem 152/396: Implement Stack Using Queues
# ❌ Error embedding text: Implement Stack Using Queues. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Implement Stack Using Queues
# 🔎 Embedding problem 153/396: Invert Binary Tree
# ❌ Error embedding text: Invert Binary Tree. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Invert Binary Tree
# 🔎 Embedding problem 154/396: Kth Smallest Element In A Bst
# ❌ Error embedding text: Kth Smallest Element In A Bst. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Kth Smallest Element In A Bst
# 🔎 Embedding problem 155/396: Power Of Two
# ❌ Error embedding text: Power Of Two. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Power Of Two
# 🔎 Embedding problem 156/396: Implement Queue Using Stacks
# ❌ Error embedding text: Implement Queue Using Stacks. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Implement Queue Using Stacks
# 🔎 Embedding problem 157/396: Palindrome Linked List
# ❌ Error embedding text: Palindrome Linked List. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Palindrome Linked List
# 🔎 Embedding problem 158/396: Lowest Common Ancestor Of A Binary Search Tree
# ❌ Error embedding text: Lowest Common Ancestor Of A Binary Search Tree. No...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Lowest Common Ancestor Of A Binary Search Tree
# 🔎 Embedding problem 159/396: Lowest Common Ancestor Of A Binary Tree
# ❌ Error embedding text: Lowest Common Ancestor Of A Binary Tree. No descri...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Lowest Common Ancestor Of A Binary Tree
# 🔎 Embedding problem 160/396: Product Of Array Except Self
# ❌ Error embedding text: Product Of Array Except Self. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Product Of Array Except Self
# 🔎 Embedding problem 161/396: Sliding Window Maximum
# ❌ Error embedding text: Sliding Window Maximum. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sliding Window Maximum
# 🔎 Embedding problem 162/396: Different Ways To Add Parentheses
# ❌ Error embedding text: Different Ways To Add Parentheses. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Different Ways To Add Parentheses
# 🔎 Embedding problem 163/396: Valid Anagram
# ❌ Error embedding text: Valid Anagram. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Valid Anagram
# 🔎 Embedding problem 164/396: Meeting Rooms
# ❌ Error embedding text: Meeting Rooms. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Meeting Rooms
# 🔎 Embedding problem 165/396: Meeting Rooms Ii
# ❌ Error embedding text: Meeting Rooms Ii. No description available. def mi...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Meeting Rooms Ii
# 🔎 Embedding problem 166/396: Meeting Rooms
# ❌ Error embedding text: Meeting Rooms. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Meeting Rooms
# 🔎 Embedding problem 167/396: Graph Valid Tree
# ❌ Error embedding text: Graph Valid Tree. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Graph Valid Tree
# 🔎 Embedding problem 168/396: Ugly Number
# ❌ Error embedding text: Ugly Number. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Ugly Number
# 🔎 Embedding problem 169/396: Missing Number
# ❌ Error embedding text: Missing Number. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Missing Number
# 🔎 Embedding problem 170/396: Alien Dictionary
# ❌ Error embedding text: Alien Dictionary. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Alien Dictionary
# 🔎 Embedding problem 171/396: Encode And Decode Strings
# ❌ Error embedding text: Encode And Decode Strings. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Encode And Decode Strings
# 🔎 Embedding problem 172/396: H Index
# ❌ Error embedding text: H Index. No description available. class Solution:...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: H Index
# 🔎 Embedding problem 173/396: First Bad Version
# ❌ Error embedding text: First Bad Version. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: First Bad Version
# 🔎 Embedding problem 174/396: Wiggle Sort
# ❌ Error embedding text: Wiggle Sort. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Wiggle Sort
# 🔎 Embedding problem 175/396: Move Zeroes
# ❌ Error embedding text: Move Zeroes. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Move Zeroes
# 🔎 Embedding problem 176/396: Walls And Gates
# ❌ Error embedding text: Walls And Gates. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Walls And Gates
# 🔎 Embedding problem 177/396: Find The Duplicate Number
# ❌ Error embedding text: Find The Duplicate Number. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find The Duplicate Number
# 🔎 Embedding problem 178/396: Word Pattern
# ❌ Error embedding text: Word Pattern. No description available. class Solu...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Word Pattern
# 🔎 Embedding problem 179/396: Find Median From Data Stream
# ❌ Error embedding text: Find Median From Data Stream. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Median From Data Stream
# 🔎 Embedding problem 180/396: Serialize And Deserialize Binary Tree
# ❌ Error embedding text: Serialize And Deserialize Binary Tree. No descript...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Serialize And Deserialize Binary Tree
# 🔎 Embedding problem 181/396: Longest Increasing Subsequence
# ❌ Error embedding text: Longest Increasing Subsequence. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Increasing Subsequence
# 🔎 Embedding problem 182/396: Range Sum Query Immutable
# ❌ Error embedding text: Range Sum Query Immutable. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Range Sum Query Immutable
# 🔎 Embedding problem 183/396: Range Sum Query 2D Immutable
# ❌ Error embedding text: Range Sum Query 2D Immutable. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Range Sum Query 2D Immutable
# 🔎 Embedding problem 184/396: Best Time To Buy And Sell Stock With Cooldown
# ❌ Error embedding text: Best Time To Buy And Sell Stock With Cooldown. No ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Best Time To Buy And Sell Stock With Cooldown
# 🔎 Embedding problem 185/396: Burst Balloons
# ❌ Error embedding text: Burst Balloons. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Burst Balloons
# 🔎 Embedding problem 186/396: Coin Change
# ❌ Error embedding text: Coin Change. No description available. class Solut...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Coin Change
# 🔎 Embedding problem 187/396: Number Of Connected Components In An Undirected Graph
# ❌ Error embedding text: Number Of Connected Components In An Undirected Gr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Connected Components In An Undirected Graph
# 🔎 Embedding problem 188/396: Longest Increasing Path In A Matrix
# ❌ Error embedding text: Longest Increasing Path In A Matrix. No descriptio...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Increasing Path In A Matrix
# 🔎 Embedding problem 189/396: Reconstruct Itinerary
# ❌ Error embedding text: Reconstruct Itinerary. No description available. c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reconstruct Itinerary
# 🔎 Embedding problem 190/396: Increasing Triplet Subsequence
# ❌ Error embedding text: Increasing Triplet Subsequence. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Increasing Triplet Subsequence
# 🔎 Embedding problem 191/396: Counting Bits
# ❌ Error embedding text: Counting Bits. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Counting Bits
# 🔎 Embedding problem 192/396: Reverse String
# ❌ Error embedding text: Reverse String. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Reverse String
# 🔎 Embedding problem 193/396: Top K Frequent Elements
# ❌ Error embedding text: Top K Frequent Elements. No description available....
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Top K Frequent Elements
# 🔎 Embedding problem 194/396: Intersection Of Two Arrays
# ❌ Error embedding text: Intersection Of Two Arrays. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Intersection Of Two Arrays
# 🔎 Embedding problem 195/396: Intersection Of Two Arrays Ii
# ❌ Error embedding text: Intersection Of Two Arrays Ii. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Intersection Of Two Arrays Ii
# 🔎 Embedding problem 196/396: Design Twitter
# ❌ Error embedding text: Design Twitter. No description available. class Tw...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Design Twitter
# 🔎 Embedding problem 197/396: Valid Perfect Square
# ❌ Error embedding text: Valid Perfect Square. No description available. cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Valid Perfect Square
# 🔎 Embedding problem 198/396: Sum Of Two Integers
# ❌ Error embedding text: Sum Of Two Integers. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sum Of Two Integers
# 🔎 Embedding problem 199/396: Guess Number Higher Or Lower
# ❌ Error embedding text: Guess Number Higher Or Lower. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Guess Number Higher Or Lower
# 🔎 Embedding problem 200/396: Combination Sum Iv
# ❌ Error embedding text: Combination Sum Iv. No description available. clas...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Combination Sum Iv
# 🔎 Embedding problem 201/396: Insert Delete Getrandom O1
# ❌ Error embedding text: Insert Delete Getrandom O1. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Insert Delete Getrandom O1
# 🔎 Embedding problem 202/396: Ransom Note
# ❌ Error embedding text: Ransom Note. No description available. from collec...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Ransom Note
# 🔎 Embedding problem 203/396: Is Subsequence
# ❌ Error embedding text: Is Subsequence. No description available. class So...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Is Subsequence
# 🔎 Embedding problem 204/396: Decode String
# ❌ Error embedding text: Decode String. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Decode String
# 🔎 Embedding problem 205/396: Remove K Digits
# ❌ Error embedding text: Remove K Digits. No description available. class S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Remove K Digits
# 🔎 Embedding problem 206/396: Split Array Largest Sum
# ❌ Error embedding text: Split Array Largest Sum. No description available....
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Split Array Largest Sum
# 🔎 Embedding problem 207/396: Partition Equal Subset Sum
# ❌ Error embedding text: Partition Equal Subset Sum. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Partition Equal Subset Sum
# 🔎 Embedding problem 208/396: Pacific Atlantic Water Flow
# ❌ Error embedding text: Pacific Atlantic Water Flow. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Pacific Atlantic Water Flow
# 🔎 Embedding problem 209/396: Longest Repeating Character Replacement
# ❌ Error embedding text: Longest Repeating Character Replacement. No descri...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Longest Repeating Character Replacement
# 🔎 Embedding problem 210/396: Non Overlapping Intervals
# ❌ Error embedding text: Non Overlapping Intervals. No description availabl...
# ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Design Browser History
# 🔎 Embedding problem 338/396: Final Prices With A Special Discount In A Shop
# ❌ Error embedding text: Final Prices With A Special Discount In A Shop. No...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Final Prices With A Special Discount In A Shop
# 🔎 Embedding problem 339/396: Least Number Of Unique Integers After K Removals
# ❌ Error embedding text: Least Number Of Unique Integers After K Removals. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Least Number Of Unique Integers After K Removals
# 🔎 Embedding problem 340/396: Find Critical And Pseudo Critical Edges In Minimum Spanning Tree
# ❌ Error embedding text: Find Critical And Pseudo Critical Edges In Minimum...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Critical And Pseudo Critical Edges In Minimum Spanning Tree
# 🔎 Embedding problem 341/396: Number Of Subsequences That Satisfy The Given Sum Condition
# ❌ Error embedding text: Number Of Subsequences That Satisfy The Given Sum ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Subsequences That Satisfy The Given Sum Condition
# 🔎 Embedding problem 342/396: Path With Maximum Probability
# ❌ Error embedding text: Path With Maximum Probability. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Path With Maximum Probability
# 🔎 Embedding problem 343/396: Count Odd Numbers In An Interval Range
# ❌ Error embedding text: Count Odd Numbers In An Interval Range. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Count Odd Numbers In An Interval Range
# 🔎 Embedding problem 344/396: Matrix Diagonal Sum
# ❌ Error embedding text: Matrix Diagonal Sum. No description available.
# cl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Matrix Diagonal Sum
# 🔎 Embedding problem 345/396: Special Positions In A Binary Matrix
# ❌ Error embedding text: Special Positions In A Binary Matrix. No descripti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Special Positions In A Binary Matrix
# 🔎 Embedding problem 346/396: Min Cost To Connect All Points
# ❌ Error embedding text: Min Cost To Connect All Points. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Min Cost To Connect All Points
# 🔎 Embedding problem 347/396: Design Parking System
# ❌ Error embedding text: Design Parking System. No description available. c...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Design Parking System
# 🔎 Embedding problem 348/396: Even Odd Tree
# ❌ Error embedding text: Even Odd Tree. No description available. class Sol...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Even Odd Tree
# 🔎 Embedding problem 349/396: Path With Minimum Effort
# ❌ Error embedding text: Path With Minimum Effort. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Path With Minimum Effort
# 🔎 Embedding problem 350/396: Furthest Building You Can Reach
# ❌ Error embedding text: Furthest Building You Can Reach. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Furthest Building You Can Reach
# 🔎 Embedding problem 351/396: Minimum Operations To Reduce X To Zero
# ❌ Error embedding text: Minimum Operations To Reduce X To Zero. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Operations To Reduce X To Zero
# 🔎 Embedding problem 352/396: Merge In Between Linked Lists
# ❌ Error embedding text: Merge In Between Linked Lists. No description avai...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge In Between Linked Lists
# 🔎 Embedding problem 353/396: Number Of Students Unable To Eat Lunch
# ❌ Error embedding text: Number Of Students Unable To Eat Lunch. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Students Unable To Eat Lunch
# 🔎 Embedding problem 354/396: Swapping Nodes In A Linked List
# ❌ Error embedding text: Swapping Nodes In A Linked List. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Swapping Nodes In A Linked List
# 🔎 Embedding problem 355/396: Minimum Length Of String After Deleting Similar Ends
# ❌ Error embedding text: Minimum Length Of String After Deleting Similar En...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Length Of String After Deleting Similar Ends
# 🔎 Embedding problem 356/396: Merge Strings Alternately
# ❌ Error embedding text: Merge Strings Alternately. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge Strings Alternately
# 🔎 Embedding problem 357/396: Maximum Ascending Subarray Sum
# ❌ Error embedding text: Maximum Ascending Subarray Sum. No description ava...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Ascending Subarray Sum
# 🔎 Embedding problem 358/396: Sign Of The Product Of An Array
# ❌ Error embedding text: Sign Of The Product Of An Array. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Sign Of The Product Of An Array
# 🔎 Embedding problem 359/396: Single Threaded Cpu
# ❌ Error embedding text: Single Threaded Cpu. No description available. cla...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Single Threaded Cpu
# 🔎 Embedding problem 360/396: Frequency Of The Most Frequent Element
# ❌ Error embedding text: Frequency Of The Most Frequent Element. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Frequency Of The Most Frequent Element
# 🔎 Embedding problem 361/396: Seat Reservation Manager
# ❌ Error embedding text: Seat Reservation Manager. No description available...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Seat Reservation Manager
# 🔎 Embedding problem 362/396: Splitting A String Into Descending Consecutive Values
# ❌ Error embedding text: Splitting A String Into Descending Consecutive Val...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Splitting A String Into Descending Consecutive Values
# 🔎 Embedding problem 363/396: Minimum Interval To Include Each Query
# ❌ Error embedding text: Minimum Interval To Include Each Query. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Interval To Include Each Query
# 🔎 Embedding problem 364/396: Minimum Number Of Flips To Make The Binary String Alternating
# ❌ Error embedding text: Minimum Number Of Flips To Make The Binary String ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Number Of Flips To Make The Binary String Alternating
# 🔎 Embedding problem 365/396: Merge Triplets To Form Target Triplet
# ❌ Error embedding text: Merge Triplets To Form Target Triplet. No descript...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Merge Triplets To Form Target Triplet
# 🔎 Embedding problem 366/396: Count Sub Islands
# ❌ Error embedding text: Count Sub Islands. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Count Sub Islands
# 🔎 Embedding problem 367/396: Concatenation Of Array
# ❌ Error embedding text: Concatenation Of Array. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Concatenation Of Array
# 🔎 Embedding problem 368/396: Unique Length 3 Palindromic Subsequences
# ❌ Error embedding text: Unique Length 3 Palindromic Subsequences. No descr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Unique Length 3 Palindromic Subsequences
# 🔎 Embedding problem 369/396: Check If Move Is Legal
# ❌ Error embedding text: Check If Move Is Legal. No description available. ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Check If Move Is Legal
# 🔎 Embedding problem 370/396: Minimum Number Of Swaps To Make The String Balanced
# ❌ Error embedding text: Minimum Number Of Swaps To Make The String Balance...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Number Of Swaps To Make The String Balanced
# 🔎 Embedding problem 371/396: Array With Elements Not Equal To Average Of Neighbors
# ❌ Error embedding text: Array With Elements Not Equal To Average Of Neighb...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Array With Elements Not Equal To Average Of Neighbors
# 🔎 Embedding problem 372/396: Find Unique Binary String
# ❌ Error embedding text: Find Unique Binary String. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Unique Binary String
# 🔎 Embedding problem 373/396: Minimum Difference Between Highest And Lowest Of K Scores
# ❌ Error embedding text: Minimum Difference Between Highest And Lowest Of K...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Difference Between Highest And Lowest Of K Scores
# 🔎 Embedding problem 374/396: Find The Kth Largest Integer In The Array
# ❌ Error embedding text: Find The Kth Largest Integer In The Array. No desc...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find The Kth Largest Integer In The Array
# 🔎 Embedding problem 375/396: Number Of Pairs Of Interchangeable Rectangles
# ❌ Error embedding text: Number Of Pairs Of Interchangeable Rectangles. No ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Pairs Of Interchangeable Rectangles
# 🔎 Embedding problem 376/396: Maximum Product Of The Length Of Two Palindromic Subsequences
# ❌ Error embedding text: Maximum Product Of The Length Of Two Palindromic S...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Product Of The Length Of Two Palindromic Subsequences
# 🔎 Embedding problem 377/396: Detect Squares
# ❌ Error embedding text: Detect Squares. No description available. class De...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Detect Squares
# 🔎 Embedding problem 378/396: Grid Game
# ❌ Error embedding text: Grid Game. No description available.
# class Soluti...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Grid Game
# 🔎 Embedding problem 379/396: Find All People With Secret
# ❌ Error embedding text: Find All People With Secret. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find All People With Secret
# 🔎 Embedding problem 380/396: Detonate The Maximum Bombs
# ❌ Error embedding text: Detonate The Maximum Bombs. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Detonate The Maximum Bombs
# 🔎 Embedding problem 381/396: Maximum Twin Sum Of A Linked List
# ❌ Error embedding text: Maximum Twin Sum Of A Linked List. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Twin Sum Of A Linked List
# 🔎 Embedding problem 382/396: Find The Difference Of Two Arrays
# ❌ Error embedding text: Find The Difference Of Two Arrays. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find The Difference Of Two Arrays
# 🔎 Embedding problem 383/396: Add Two Integers
# ❌ Error embedding text: Add Two Integers. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Add Two Integers
# 🔎 Embedding problem 384/396: Successful Pairs Of Spells And Potions
# ❌ Error embedding text: Successful Pairs Of Spells And Potions. No descrip...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Successful Pairs Of Spells And Potions
# 🔎 Embedding problem 385/396: Naming A Company
# ❌ Error embedding text: Naming A Company. No description available. class ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Naming A Company
# 🔎 Embedding problem 386/396: Number Of Zero Filled Subarrays
# ❌ Error embedding text: Number Of Zero Filled Subarrays. No description av...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Number Of Zero Filled Subarrays
# 🔎 Embedding problem 387/396: Removing Stars From A String
# ❌ Error embedding text: Removing Stars From A String. No description avail...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Removing Stars From A String
# 🔎 Embedding problem 388/396: Meeting Rooms Iii
# ❌ Error embedding text: Meeting Rooms Iii. No description available. class...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Meeting Rooms Iii
# 🔎 Embedding problem 389/396: Optimal Partition Of String
# ❌ Error embedding text: Optimal Partition Of String. No description availa...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Optimal Partition Of String
# 🔎 Embedding problem 390/396: Difference Between Ones And Zeros In Row And Column
# ❌ Error embedding text: Difference Between Ones And Zeros In Row And Colum...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Difference Between Ones And Zeros In Row And Column
# 🔎 Embedding problem 391/396: Minimum Penalty For A Shop
# ❌ Error embedding text: Minimum Penalty For A Shop. No description availab...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimum Penalty For A Shop
# 🔎 Embedding problem 392/396: Maximum Number Of Integers To Choose From A Range I
# ❌ Error embedding text: Maximum Number Of Integers To Choose From A Range ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Number Of Integers To Choose From A Range I
# 🔎 Embedding problem 393/396: Minimize The Maximum Difference Of Pairs
# ❌ Error embedding text: Minimize The Maximum Difference Of Pairs. No descr...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Minimize The Maximum Difference Of Pairs
# 🔎 Embedding problem 394/396: Greatest Common Divisor Traversal
# ❌ Error embedding text: Greatest Common Divisor Traversal. No description ...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Greatest Common Divisor Traversal
# 🔎 Embedding problem 395/396: Maximum Odd Binary Number
# ❌ Error embedding text: Maximum Odd Binary Number. No description availabl...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Maximum Odd Binary Number
# 🔎 Embedding problem 396/396: Find Polygon With The Largest Perimeter
# ❌ Error embedding text: Find Polygon With The Largest Perimeter. No descri...
# Ollama failed: Error: unknown command "embeddings" for "ollama"
#
# ⚠️ Skipping: Find Polygon With The Largest Perimeter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 49
#      46         print(f"⚠️ Skipping: {problems[i]['title']}")
#      47     time.sleep(0.1)  # Be kind to system load
# ---> 49 embeddings = np.vstack(all_embeddings).astype("float32")
#      51 # Create and save FAISS index
#      52 dim = embeddings.shape[1]
#
# File c:\Users\prana\anaconda3\Lib\site-packages\numpy\core\shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate

# %%
import json
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

# Load model
model = SentenceTransformer("all-MiniLM-L6-v2")

def build_faiss_index(json_path, faiss_index_path, updated_json_path):
    # Load problem JSON
    with open(json_path, "r", encoding="utf-8") as f:
        problems = json.load(f)

    texts = []
    valid_problems = []

    for p in problems:
        title = p.get("title", "Untitled")
        description = p.get("description", "")
        code = p.get("optimal_code", "").strip()
        
        if not code:
            print(f"⚠️ Skipping {title}: no code")
            continue
        
        # Construct text input
        full_text = f"{title}. {description} {code}".strip()
        texts.append(full_text)
        valid_problems.append(p)

    if not texts:
        print("❌ No valid problems to embed.")
        return

    print(f"🔍 Generating embeddings for {len(texts)} problems...")
    embeddings = model.encode(texts, show_progress_bar=True, convert_to_numpy=True)

    # Build FAISS index
    dim = embeddings.shape[1]
    index = faiss.IndexFlatL2(dim)
    index.add(embeddings)
    faiss.write_index(index, faiss_index_path)

    # Save the updated (valid) JSON
    with open(updated_json_path, "w", encoding="utf-8") as f:
        json.dump(valid_problems, f, indent=2, ensure_ascii=False)

    print(f"\n✅ FAISS index saved to {faiss_index_path}")
    print(f"📄 Filtered problem dataset saved to {updated_json_path}")

# --- Run this script ---
if __name__ == "__main__":
    build_faiss_index(
        json_path="neetcode_problems.json",
        faiss_index_path="rag_minilm_index.faiss",
        updated_json_path="rag_minilm_problems.json"
    )
# Out:
# WARNING:tensorflow:From c:\Users\prana\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 🔍 Generating embeddings for 396 problems...
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]
# ✅ FAISS index saved to rag_minilm_index.faiss
# 📄 Filtered problem dataset saved to rag_minilm_problems.json

# %%
import json
import numpy as np
import faiss
from sentence_transformers import SentenceTransformer

# Load model & data
model = SentenceTransformer("all-MiniLM-L6-v2")
index = faiss.read_index("rag_minilm_index.faiss")

with open("rag_minilm_problems.json", "r", encoding="utf-8") as f:
    problems = json.load(f)

def retrieve_similar_problems(query, k=5):
    query_vec = model.encode([query], convert_to_numpy=True)
    distances, indices = index.search(query_vec, k)
    results = [problems[i] for i in indices[0]]
    return results

# %%
def build_prompt(retrieved, query):
    context = ""
    for p in retrieved:
        context += f"### {p['title']}\n"
        context += f"{p['description']}\n"
        context += f"Optimal Code:\n{p['optimal_code']}\n"
        context += f"Time: {p['time_complexity']} | Space: {p['space_complexity']}\n\n"

    prompt = f"""You are a coding assistant. Based on the following context, answer the user's question.

{context}
--- End of context ---

User question: {query}
Answer:"""
    return prompt

# %%
import subprocess

OLLAMA_PATH = "C:/Users/prana/AppData/Local/Programs/Ollama/ollama.exe"
MODEL_NAME = "llama3"

def generate_answer(prompt):
    result = subprocess.run(
        [OLLAMA_PATH, "run", MODEL_NAME],
        input=prompt,
        capture_output=True,
        text=True,
        timeout=60
    )
    return result.stdout.strip()

# %%
if __name__ == "__main__":
    query = input("🔍 Ask a coding question: ").strip()

    print("🔎 Retrieving relevant problems...")
    retrieved = retrieve_similar_problems(query, k=5)

    print("✍️  Building prompt...")
    prompt = build_prompt(retrieved, query)

    print("🧠 Generating answer...")
    response = generate_answer(prompt)

    print("\n✅ Answer:\n")
    print(response)
# Out:
# 🔎 Retrieving relevant problems...
# ✍️  Building prompt...
# 🧠 Generating answer...
#
# ✅ Answer:
#
# A new challenge!
#
# To efficiently solve the "Kth Smallest Product of Two Sorted Arrays" problem, we can use a similar approach to the "Find K Closest Elements" problem.
#
# Here's an optimal solution:
# ```python
# class Solution:
#     def kthSmallestProduct(self, arr1: List[int], arr2: List[int], k: int) -> int:
#         n = len(arr1)
#         m = len(arr2)
#         res = float('inf')
#
#         l, r = 0, n - 1
#         while l <= r:
#             mid = (l + r) // 2
#             prod = arr1[mid] * arr2[0]
#             if prod < k:
#                 l = mid + 1
#             elif prod > k:
#                 r = mid - 1
#             else:
#                 break
#
#         for i in range(k):
#             if l == n:
#                 return -1
#             res = min(res, arr1[l] * arr2[i])
#
#         return res
# ```
# Here's how it works:
#
# 1. Find the middle element of `arr1` and calculate its product with the first element of `arr2`. If this product is less than `k`, move to the right half of `arr1`.
# 2. If the product is greater than `k`, move to the left half of `arr1`.
# 3. Once we find the correct range in `arr1`, calculate the products of all pairs of elements within that range and keep track of the smallest one.
# 4. If `k` exceeds the length of the result, return `-1`.
#
# This solution has a time complexity of O(n + m), where n is the length of `arr1` and m is the length of `arr2`. The space complexity remains O(1).
#
# Note that this problem requires a combination of binary search and product calculation.

# %%
import json
import subprocess
from tqdm import tqdm

# Load your JSON file
with open("rag_minilm_problems.json", "r", encoding="utf-8") as f:
    problems = json.load(f)

def get_approach(code: str) -> str:
    prompt = f"""Given the following optimal solution, what is the main algorithmic approach used?
Choose from common terms like: "Hash Map", "Two Pointers", "Sliding Window", "DFS", "BFS", "Sorting", "Binary Search", "Greedy", "Dynamic Programming", etc.

Code:
{code}

Just return the main approach name."""
    
    proc = subprocess.run(
        [r"C:\Users\prana\AppData\Local\Programs\Ollama\ollama.exe", "run", "llama3"],
        input=prompt.encode(), stdout=subprocess.PIPE
    )
    return proc.stdout.decode().strip().splitlines()[0]

# Add approach field to each problem
for p in tqdm(problems):
    if "approach" not in p or not p["approach"].strip():
        try:
            p["approach"] = get_approach(p["optimal_code"])
        except:
            p["approach"] = "Unknown"

# Save back to file
with open("rag_minilm_problems.json", "w", encoding="utf-8") as f:
    json.dump(problems, f, indent=2, ensure_ascii=False)

print("✅ Done tagging all problems with approaches.")
# Out:
# 100%|██████████| 396/396 [07:12<00:00,  1.09s/it]
# ✅ Done tagging all problems with approaches.
